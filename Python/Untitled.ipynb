# %%
from pylab import *
from numpy import *

# %%
file = open('logtimings.txt','r')

x=zeros(1)
h=0
for s in file:
    
    s=file.readline()
    print(s[0:])
    #if s[0:5]=='Step=':
        #print(s[0:5])
        #n=''
        #i=6
        #while s[i] != ' ':
        #    n=n+s[i]
        #    i=i+1
        #print(n)
        #h=h+1
print(s)
# Out:
# Nf= 0002097152  total-Nf= 0002097152  ex-frac= 2.3203  iter= 1
#
# particle-load balance: 1.01279
#
# part/sec=20143.1 | 16776.3  ia/part=666.326 (0)
#
# Step= 0  t= 0.000999001  dt= 0
#
# work-load balance: 1.20534  max=82.3411 avg=68.3135 PE0=61.9928
#
# max. nodes: 27388, filled: 0.163245
#
#
#
# Nf= 0002097152  total-Nf= 0006291456  ex-frac= 2.36395  iter= 1
#
# particle-load balance: 1.10822
#
# part/sec=1889.25 | 1595.5  ia/part=8290.68 (0)
#
# Step= 2  t= 0.0010544  dt= 2.8075e-05
#
# work-load balance: 1.12371  max=77.0622 avg=68.5785 PE0=60.9209
#
# max. nodes: 29820, filled: 0.177741
#
#
#
# Nf= 0002097152  total-Nf= 0010485760  ex-frac= 2.39363  iter= 1
#
# particle-load balance: 1.11343
#
# part/sec=1942.75 | 1670.38  ia/part=8078.74 (0)
#
# Step= 4  t= 0.00111288  dt= 2.9632e-05
#
# work-load balance: 1.14939  max=76.5983 avg=66.6425 PE0=54.6383
#
# max. nodes: 29568, filled: 0.176239
#
#
#
# Nf= 0002097152  total-Nf= 0014680064  ex-frac= 2.4012  iter= 1
#
# ...
